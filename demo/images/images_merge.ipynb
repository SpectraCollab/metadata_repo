# %% [markdown]
# # Merging information tables
#
# In this notebook, we:
# - Read image information organized in tabular data as dataframes
# - Merge the dataframes
# - Save the resulting dataframe
#
#
# By Serena Bonaretti
#
# ---

# %% [markdown]
# Imports and variables:

# %%
import os
import pandas as pd

# %%
folder = "./"

# %% [markdown]
# ---
# ## 1. Getting the names of the tabular files in the folder:

# %%
# getting the folder content
folder_content = os.listdir(folder)

# creating the list for .pdf file names
file_names = [] 

# getting only .isq files
for file_name in folder_content: 
    
    # getting file extensions
    file_name_again, file_extension = os.path.splitext(folder + file_name)
    
    # get only the files with .pdf or .PDF file extension
    if ("csv" in file_extension or "xlsx" in file_extension) and file_name != "images_info.csv":
        file_names.append(file_name)
        
print ("-> Found " + str(len(file_names)) + " .csv or .xlsx files in folder:" )

for filename in file_names:
    print (filename)
# Out:
# -> Found 2 .csv or .xlsx files in folder:
# images_3300.csv
# images_3309.csv

# %% [markdown]
# ---
# ## 2. Reading the files and merging them:

# %%
# display all pandas columns and rows 
pd.options.display.max_rows    = None
pd.options.display.max_columns = None

# %% [markdown]
# - Read the first file:

# %%
file_name, file_extension = os.path.splitext(folder + file_names[0])
if file_extension == ".csv":
    subjects_info = pd.read_csv(file_names[0])
else:
    subjects_info = pd.read_excel(file_names[0])
subjects_info
# Out:
#         file_name             check  data_type  nr_of_bytes  nr_of_blocks  \
# 0  S0006767.ISQ;1  CTDATA-HEADER_V1          3   1557138432       3041286
# 1  S0006514.ISQ;1  CTDATA-HEADER_V1          3   1557138432       3041286
# 2  S0006589.ISQ;1  CTDATA-HEADER_V1          3   1557138432       3041286
# 3  S0006755.ISQ;1  CTDATA-HEADER_V1          3   1557138432       3041286
#
#    pat_no  scanner_id        date  n_voxels_x  n_voxels_y  n_voxels_z  \
# 0     440        3300  2013_03_27        1536        1536         330
# 1     426        3300  2013_02_12        1536        1536         330
# 2     431        3300  2013_02_25        1536        1536         330
# 3     437        3300  2013_03_26        1536        1536         330
#
#    total_size_um_x  total_size_um_y  total_size_um_z  slice_thickness_um  \
# 0           125952           125952            27060                  82
# 1           125952           125952            27060                  82
# 2           125952           125952            27060                  82
# 3           125952           125952            27060                  82
#
#    pixel_size_um  slice_1_pos_um  min_intensity  max_intensity  mu_scaling  \
# 0             82           48227          -1766           9928        8192
# 1             82           56270          -2814          10518        8192
# 2             82           48449          -1915          11070        8192
# 3             82           44315          -2936          11935        8192
#
#    nr_of_samples  nr_of_projections  scan_dist_um  scanner_type  \
# 0           1536                750        125952             9
# 1           1536                750        125952             9
# 2           1536                750        125952             9
# 3           1536                750        125952             9
#
#    exposure_time  meas_no  site  reference_line_um  recon_algo  \
# 0         100000     1909     4                  0           3
# 1         100000     1841     4                  0           3
# 2         100000     1863     4                  0           3
# 3         100000     1896     4                  0           3
#
#                                    pat_name  energy_V  intensity_uA  \
# 0  MCP_MAIN7                                    59400           900
# 1  MCP_MAIN2                                    59400           900
# 2  MCP_MAIN4                                    59400           900
# 3  MCP_MAIN6                                    59400           900
#
#    data_offset
# 0            5
# 1            5
# 2            5
# 3            5

# %% [markdown]
# - Read other files and merge them:

# %%
for i in range (1, len(file_names)):
    
    # read current table
    file_name, file_extension = os.path.splitext(folder + file_names[i])
    if file_extension == ".csv":
        current_subjects_info = pd.read_csv(file_names[i])
    else:
        current_subjects_info = pd.read_excel(file_names[i])
        
    # merge the table
    subjects_info = pd.concat([subjects_info, current_subjects_info])

subjects_info
# Out:
#               file_name             check  data_type  nr_of_bytes  \
# 0        S0006767.ISQ;1  CTDATA-HEADER_V1          3   1557138432
# 1        S0006514.ISQ;1  CTDATA-HEADER_V1          3   1557138432
# 2        S0006589.ISQ;1  CTDATA-HEADER_V1          3   1557138432
# 3        S0006755.ISQ;1  CTDATA-HEADER_V1          3   1557138432
# 0        C0008472.ISQ;1  CTDATA-HEADER_V1          3            0
# 1        C0010013.ISQ;1  CTDATA-HEADER_V1          3   1557138432
# 2  CJS_R_C0012934.ISQ;1  CTDATA-HEADER_V1          3   1038093312
#
#    nr_of_blocks  pat_no  scanner_id        date  n_voxels_x  n_voxels_y  \
# 0       3041286     440        3300  2013_03_27        1536        1536
# 1       3041286     426        3300  2013_02_12        1536        1536
# 2       3041286     431        3300  2013_02_25        1536        1536
# 3       3041286     437        3300  2013_03_26        1536        1536
# 0        506886    2745        3309  2011_12_22         768         768
# 1       3041286    2746        3309  2012_02_10        1536        1536
# 2       2027526    3643        3309  2013_10_01        1536        1536
#
#    n_voxels_z  total_size_um_x  total_size_um_y  total_size_um_z  \
# 0         330           125952           125952            27060
# 1         330           125952           125952            27060
# 2         330           125952           125952            27060
# 3         330           125952           125952            27060
# 0         220            62976            62976            18040
# 1         330           125952           125952            27060
# 2         220           125952           125952            18040
#
#    slice_thickness_um  pixel_size_um  slice_1_pos_um  min_intensity  \
# 0                  82             82           48227          -1766
# 1                  82             82           56270          -2814
# 2                  82             82           48449          -1915
# 3                  82             82           44315          -2936
# 0                  82             82          107081          -1695
# 1                  82             82           88161          -2913
# 2                  82             82          128525         -12332
#
#    max_intensity  mu_scaling  nr_of_samples  nr_of_projections  scan_dist_um  \
# 0           9928        8192           1536                750        125952
# 1          10518        8192           1536                750        125952
# 2          11070        8192           1536                750        125952
# 3          11935        8192           1536                750        125952
# 0          10801        8192           1536                750        125952
# 1          11085        8192           1536                750        125952
# 2          20959        8192           1536                750        125952
#
#    scanner_type  exposure_time  meas_no  site  reference_line_um  recon_algo  \
# 0             9         100000     1909     4                  0           3
# 1             9         100000     1841     4                  0           3
# 2             9         100000     1863     4                  0           3
# 3             9         100000     1896     4                  0           3
# 0             9         100000     9538     4                  0           3
# 1             9         100000    11111     4                  0           3
# 2             9         100000    13628     4                  0           3
#
#                                    pat_name  energy_V  intensity_uA  \
# 0  MCP_MAIN7                                    59400           900
# 1  MCP_MAIN2                                    59400           900
# 2  MCP_MAIN4                                    59400           900
# 3  MCP_MAIN6                                    59400           900
# 0                                   EUA_001     59400          1000
# 1  EUA_002                                      59400          1000
# 2  CJS_3043R                                    59400           900
#
#    data_offset
# 0            5
# 1            5
# 2            5
# 3            5
# 0            0
# 1            5
# 2            5

# %% [markdown]
# ---
# ## 3. Saving the table to a *.csv* or *.xlsx* file
#
# We can save the dataframe to several different file formats. Here we save it as:
# - *.csv* (open source)
# - *.xlsx* (proprietary)

# %%
# save to csv
subjects_info.to_csv("images_info.csv", index=False)

# save to excel
# subjects_info.to_excel("images_info.xlsx", index=False)

# %% [markdown]
# ---
# ## Dependencies

# %%
# %load_ext watermark
# %watermark -v -m -p pandas
# Out:
# Python implementation: CPython
# Python version       : 3.8.5
# IPython version      : 7.22.0
#
# pandas: 1.2.4
#
# Compiler    : Clang 10.0.0
# OS          : Darwin
# Release     : 20.5.0
# Machine     : x86_64
# Processor   : i386
# CPU cores   : 4
# Architecture: 64bit
